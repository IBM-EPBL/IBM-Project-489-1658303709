# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn import metrics 
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("dataset_website.csv")
data.head()
# Out:
#    index  having_IPhaving_IP_Address  URLURL_Length  Shortining_Service  \
# 0      1                          -1              1                   1
# 1      2                           1              1                   1
# 2      3                           1              0                   1
# 3      4                           1              0                   1
# 4      5                           1              0                  -1
#
#    having_At_Symbol  double_slash_redirecting  Prefix_Suffix  \
# 0                 1                        -1             -1
# 1                 1                         1             -1
# 2                 1                         1             -1
# 3                 1                         1             -1
# 4                 1                         1             -1
#
#    having_Sub_Domain  SSLfinal_State  Domain_registeration_length  ...  \
# 0                 -1              -1                           -1  ...
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
df = data[['Shortining_Service', 'having_IPhaving_IP_Address', 'Domain_registeration_length','popUpWidnow','web_traffic','Google_Index']]
sns.pairplot(data = df,hue="Google_Index",corner=True);
